# %%
import pandas as pd

# %% [markdown]
# # Read Cost of Living CSV File and Begin Cleaning Data

# %%
# Read csv file
col_data_df = pd.read_csv('Resources/Cost_of_Living_Docs/cost_of_living.csv')
col_data_df.head()
# Out:
#    case_id state_abv  county_fips          county family  housing  \
# 0      1.0        AL       1001.0  Autauga County   1p0c    817.0
# 1      1.0        AL       1001.0  Autauga County   1p1c   1114.0
# 2      1.0        AL       1001.0  Autauga County   1p2c   1114.0
# 3      1.0        AL       1001.0  Autauga County   1p3c   1416.0
# 4      1.0        AL       1001.0  Autauga County   1p4c   1416.0
#
#    food_monthly  transportation_monthly  healthcare_monthly  misc_monthly  \
# 0         335.0                  1110.0               510.0         408.0
# 1         494.0                  1365.0               756.0         570.0
# 2         723.0                  1570.0              1003.0         651.0
# 3         966.0                  1670.0              1249.0         843.0
# 4        1182.0                  1742.0              1495.0         920.0
#
#    ...  healthcare_yearly  misc_yearly  childcare_yearly taxes_yearly  \
# ...

# %%
# Create a copy of the original DataFrame
col_data_df_copy = col_data_df.copy()

# %%
# Drop the 'county_fips', 'case_id', 'housing', 'food_monthly', 'transportation_monthly', 'healthcare_monthly', 'misc_monthly', 'childcare_monthly', 'taxes_monthly', 'total_monthly' columns from copy
col_data_df_copy = col_data_df_copy.drop(columns=['county_fips', 'case_id', 'housing', 'food_monthly', 'transportation_monthly', 'healthcare_monthly', 'misc_monthly', 'childcare_monthly', 'taxes_monthly', 'total_monthly'])

# Verify the column has been dropped
col_data_df_copy.head()
# Out:
#   state_abv          county family housing_yearly food_yearly  \
# 0        AL  Autauga County   1p0c         $9,804      $4,020
# 1        AL  Autauga County   1p1c        $13,368      $5,928
# 2        AL  Autauga County   1p2c        $13,368      $8,676
# 3        AL  Autauga County   1p3c        $16,992     $11,592
# 4        AL  Autauga County   1p4c        $16,992     $14,184
#
#   transportation_yearly healthcare_yearly misc_yearly childcare_yearly  \
# 0               $13,320            $6,120      $4,896               $0
# 1               $16,380            $9,072      $6,840           $6,240
# 2               $18,840           $12,036      $7,812          $12,144
# 3               $20,040           $14,988     $10,116          $13,956
# 4               $20,904           $17,940     $11,040          $13,956
#
#   taxes_yearly total_yearly median_family_income  num_counties_in_st  \
# 0       $7,488      $45,636              83,790                 67.0
# ...

# %%
col_data_df_copy.head(10)
# Out:
#   state_abv          county family housing_yearly food_yearly  \
# 0        AL  Autauga County   1p0c         $9,804      $4,020
# 1        AL  Autauga County   1p1c        $13,368      $5,928
# 2        AL  Autauga County   1p2c        $13,368      $8,676
# 3        AL  Autauga County   1p3c        $16,992     $11,592
# 4        AL  Autauga County   1p4c        $16,992     $14,184
# 5        AL  Autauga County   2p0c        $11,184      $7,380
# 6        AL  Autauga County   2p1c        $13,368      $9,180
# 7        AL  Autauga County   2p2c        $13,368     $11,616
# 8        AL  Autauga County   2p3c        $16,992     $14,196
# 9        AL  Autauga County   2p4c        $16,992     $17,376
#
#   transportation_yearly healthcare_yearly misc_yearly childcare_yearly  \
# 0               $13,320            $6,120      $4,896               $0
# 1               $16,380            $9,072      $6,840           $6,240
# ...

# %%
# Save the updated DataFrame to a new CSV file
col_data_df_copy.to_csv('Resources/Cost_of_Living_Docs/updated_col_data.csv', index=False)
