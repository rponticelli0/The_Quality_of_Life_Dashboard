# %%
import pandas as pd

# %% [markdown]
# # Read Average Salary per Occupation CSV File and Begin Cleaning Data

# %%
# Read csv file
salary_data_df = pd.read_csv('Resources/OEWS_Docs/salary_data.csv')
salary_data_df.head()
# Out:
#     area       county  area_type state_abv  naics     naics_title  \
# 0  10180  Abilene, TX          4        TX      0  Cross-industry
# 1  10180  Abilene, TX          4        TX      0  Cross-industry
# 2  10180  Abilene, TX          4        TX      0  Cross-industry
# 3  10180  Abilene, TX          4        TX      0  Cross-industry
# 4  10180  Abilene, TX          4        TX      0  Cross-industry
#
#           i_group  own_code occ_code                        occ_title  ...  \
# 0  cross-industry      1235  00-0000                  All Occupations  ...
# 1  cross-industry      1235  11-0000           Management Occupations  ...
# 2  cross-industry      1235  11-1011                 Chief Executives  ...
# 3  cross-industry      1235  11-1021  General and Operations Managers  ...
# 4  cross-industry      1235    44501               Marketing Managers  ...
#
#   h_pct10 h_pct25 h_median h_pct75 h_pct90 a_pct10  a_pct25 a_median  a_pct75  \
# ...

# %%
# Create a copy of the original DataFrame
salary_data_df_copy = salary_data_df.copy()

# %%
salary_data_df_copy.columns
# Out:
# Index(['area', 'county', 'area_type', 'state_abv', 'naics', 'naics_title',
#        'i_group', 'own_code', 'occ_code', 'occ_title', 'o_group', 'tot_emp',
#        'emp_prse', 'jobs_1000', 'loc_quotient', 'h_mean', 'a_mean',
#        'mean_prse', 'h_pct10', 'h_pct25', 'h_median', 'h_pct75', 'h_pct90',
#        'a_pct10', 'a_pct25', 'a_median', 'a_pct75', 'a_pct90'],
#       dtype='object')

# %%
# Drop the  columns from copy
salary_data_df_copy = salary_data_df_copy.drop(columns=['area', 'area_type', 'naics', 'naics_title', 'i_group', 'own_code', 'o_group'])

# Verify the column has been dropped
salary_data_df_copy.head()
# Out:
#         county state_abv occ_code                        occ_title tot_emp  \
# 0  Abilene, TX        TX  00-0000                  All Occupations  72,780
# 1  Abilene, TX        TX  11-0000           Management Occupations   4,930
# 2  Abilene, TX        TX  11-1011                 Chief Executives      40
# 3  Abilene, TX        TX  11-1021  General and Operations Managers   2,290
# 4  Abilene, TX        TX    44501               Marketing Managers     120
#
#   emp_prse jobs_1000 loc_quotient  h_mean   a_mean  ... h_pct10 h_pct25  \
# 0      0.0  1000.000         1.00   23.93   49,780  ...   10.94   13.80
# 1      1.1    67.752         0.98   48.41  100,690  ...   20.23   28.50
# 2      8.2     0.561         0.40  115.39  240,020  ...   47.35   65.04
# 3      2.0    31.404         1.36   47.35   98,480  ...   16.56   23.77
# 4      8.9     1.675         0.69   55.91  116,290  ...   28.91   36.05
#
#   h_median h_pct75 h_pct90 a_pct10  a_pct25 a_median  a_pct75  a_pct90
# ...

# %%
# Apply the string split method to remove everything after the comma
salary_data_df_copy['county'] = salary_data_df_copy['county'].str.split(',').str[0]

salary_data_df_copy.head()
# Out:
#     county state_abv occ_code                        occ_title tot_emp  \
# 0  Abilene        TX  00-0000                  All Occupations  72,780
# 1  Abilene        TX  11-0000           Management Occupations   4,930
# 2  Abilene        TX  11-1011                 Chief Executives      40
# 3  Abilene        TX  11-1021  General and Operations Managers   2,290
# 4  Abilene        TX    44501               Marketing Managers     120
#
#   emp_prse jobs_1000 loc_quotient  h_mean   a_mean  ... h_pct10 h_pct25  \
# 0      0.0  1000.000         1.00   23.93   49,780  ...   10.94   13.80
# 1      1.1    67.752         0.98   48.41  100,690  ...   20.23   28.50
# 2      8.2     0.561         0.40  115.39  240,020  ...   47.35   65.04
# 3      2.0    31.404         1.36   47.35   98,480  ...   16.56   23.77
# 4      8.9     1.675         0.69   55.91  116,290  ...   28.91   36.05
#
#   h_median h_pct75 h_pct90 a_pct10  a_pct25 a_median  a_pct75  a_pct90
# ...

# %%
# Save the updated DataFrame to a new CSV file
salary_data_df_copy.to_csv('updated_salary_data.csv', index=False)
